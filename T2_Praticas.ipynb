# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardoluisvieira/mackenzie/blob/main/T2_Praticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
inflacao = pd.read_csv ('https://raw.githubusercontent.com/eduardoluisvieira/mackenzie/main/STP-inflacao.csv', delimiter=';',decimal=',')

# %%
inflacao.head
# Out:
# <bound method NDFrame.head of        Data   IPCA  IPCA_Servico
# 0    jan/92  25.94         25.84
# 1    fev/92  24.32         22.17
# 2    mar/92  21.40         20.74
# 3    abr/92  19.93         20.14
# 4    mai/92  24.86         26.93
# ..      ...    ...           ...
# 356  set/21   1.16          0.63
# 357  out/21   1.25          1.04
# 358  nov/21   0.95          0.27
# 359  dez/21   0.73          0.79
# 360  jan/22   0.54          0.39
#
# [361 rows x 3 columns]>

# %%
plt.figure(figsize=(20,5), dpi = 80)
IPCA_Servicos = inflacao[ inflacao.IPCA == 'IPCA' ]
IPCA_Geral = inflacao[ inflacao.IPCA_Servico == 'IPCA Servico' ]

#plt.subplot(1,2,1)
plt.plot(inflacao['Data'],inflacao['IPCA'],'-')
#plt.plot(inflacao.Data, inflacao.IPCA, label='IPCA')
# plt.plot(inflacao.Data, inflacao.IPCA_Servico, label='IPCA_Servico')
plt.title('Inflação IPCA x IPCA Serviços',fontsize=14,weight='bold')
plt.legend()

#plt.tight_layout()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Média do IPCA:
IPCA_Series = inflacao['IPCA']
print (f'Média do IPCA:{IPCA_Series.mean():.2f}%')
# Out:
# Média do IPCA:3.07%

# %%
# Média do IPCA de Serviços
IPCAServico_Series = inflacao['IPCA_Servico']
print (f'Média do IPCA de Serviços:{IPCAServico_Series.mean():.2f}%')
# Out:
# Média do IPCA de Serviços:3.09%

# %%
# As cinco menores taxas de inflação
inflacao.nsmallest(5,'IPCA')
# Out:
#        Data  IPCA  IPCA_Servico
# 79   ago/98 -0.51          0.00
# 340  mai/20 -0.38         -0.45
# 339  abr/20 -0.31          0.25
# 305  jun/17 -0.23          0.43
# 80   set/98 -0.22         -0.14

# %%
# As cinco maiores taxas de inflação
inflacao.nlargest(5,'IPCA')
# Out:
#       Data   IPCA  IPCA_Servico
# 29  jun/94  47.43         43.79
# 28  mai/94  44.03         45.42
# 26  mar/94  42.75         43.95
# 27  abr/94  42.68         41.83
# 24  jan/94  41.31         42.08

# %%
# IPCA > 10%
IPCA_10 = inflacao[inflacao.IPCA > 10.0][['IPCA', 'IPCA_Servico']]
IPCA_10
# Out:
#      IPCA  IPCA_Servico
# 0   25.94         25.84
# 1   24.32         22.17
# 2   21.40         20.74
# 3   19.93         20.14
# 4   24.86         26.93
# 5   20.21         19.07
# 6   21.83         22.00
# 7   22.14         18.58
# 8   24.63         25.03
# 9   25.24         22.65
# 10  22.49         20.42
# 11  25.24         22.43
# 12  30.35         31.20
# 13  24.98         23.54
# 14  27.26         28.86
# 15  27.75         25.00
# 16  27.69         28.41
# 17  30.07         29.11
# 18  30.72         28.78
# 19  32.96         33.50
# 20  35.69         36.36
# 21  33.92         32.08
# 22  35.56         33.01
# 23  36.84         33.85
# 24  41.31         42.08
# 25  40.27         41.38
# 26  42.75         43.95
# 27  42.68         41.83
# 28  44.03         45.42
# 29  47.43         43.79

# %%
len(IPCA_10)
# Out:
# 30

# %%
# histograma
plt.hist(IPCA_10.IPCA, label = 'IPCA')
plt.hist(IPCA_10.IPCA_Servico, label = 'IPCA Serviços')
plt.title('IPCA > 10%')
plt.legend()
plt.show()
