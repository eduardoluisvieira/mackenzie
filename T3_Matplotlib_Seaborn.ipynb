# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardoluisvieira/mackenzie/blob/main/T3_Matplotlib_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports empregados nesta seção. Eles podem se repetir abaixo para enfatizar os recursos.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Exemplo de gráfico simples com a biblioteca
import numpy as np

import matplotlib.pyplot as plt             
# %matplotlib inline

x = np.arange(-10,10,0.01)

plt.plot(x, np.sin(x))
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt             
# %matplotlib inline

x = np.arange(-10,10,0.01)

plt.plot(x, np.sin(x), label='sin(x)')
# exibindo o primeiro gráfico separado dos outros 2
plt.show()

# exibindo os dois outros combinados em um único gráfico
plt.plot(x, np.cos(4*x), label='cos(4x)')
plt.plot(x, np.sin(8*x),label='cos(8x)')

plt.title('Exemplo Sin(x) & Cos(4x)')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(12,4)) # cria uma figura alterando o tamanho, figsize=(tamanho_horizontal,tamanho_vertical)

plt.suptitle('Script Layer', fontsize=14, weight='bold', y=1.05)

# cria e ativa um gráfico na figura
plt.subplot(1, 3, 1) # (linhas, colunas, gráfico ativo)
plt.plot(x, np.sin(x))
plt.title('Primeiro plot')

# cria e ativa um segundo gráfico na figura
plt.subplot(1, 3, 2) # (linhas, colunas, gráfico ativo)
plt.plot(x, np.cos(4*x));
plt.title('Segundo plot')

# cria e ativa um segundo gráfico na figura
plt.subplot(1, 3, 3) # (linhas, colunas, gráfico ativo)
plt.plot(x, np.cos(4*x));
plt.title('Terceiro plot')

plt.tight_layout()
plt.show()

# %%
# Cria uma grade de gráficos com 1 linha e 2 colunas de gráficos, ax é um vetor em que cada elemento corresponde a um gráfico da grade
fig, ax = plt.subplots(1,3,figsize=(12,4)) # foram declarados 3 gráficos (1,3) e cria uma figura alterando o tamanho, figsize=(tamanho_horizontal,tamanho_vertical)

plt.suptitle('Artist Layer', fontsize=14, weight='bold', y=1.05)

# Os comandos podem então ser direcionados para o gráfico específico
ax[0].plot(x, np.sin(x))
ax[0].set_title('Primeiro plot')

ax[1].plot(x, np.cos(4*x));
ax[1].set_title('Segundo plot')

ax[2].plot(x, np.cos(8*x));
ax[2].set_title('Terceiro plot')

plt.tight_layout()
plt.show()
